# %%
# %matplotlib inline

from pathlib import Path

import math
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import statsmodels.formula.api as sm
from statsmodels.tsa import tsatools, stattools
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics import tsaplots

# %%
def singleGraphLayout(ax, ylim, train_df, valid_df):
    ax.set_xlim('1990','2004-6')
    ax.set_ylim(*ylim)
    ax.set_xlabel('Time')
    one_month = pd.Timedelta('31 days')
    xtrain = (min(train_df.index), max(train_df.index) - one_month)
    xvalid = (min(valid_df.index) + one_month, max(valid_df.index) - one_month)
    xtv = xtrain[1] + 0.5 * (xvalid[0] - xtrain[1])
    
    ypos = 0.9 * ylim[1] + 0.1 * ylim[0]
    ax.add_line(plt.Line2D(xtrain, (ypos, ypos), color='black', linewidth=0.5))
    ax.add_line(plt.Line2D(xvalid, (ypos, ypos), color='black', linewidth=0.5))
    ax.axvline(x=xtv, ymin=0, ymax=1, color='black',linewidth=0.5)
    
    ypos = 0.925 * ylim[1] + 0.075 * ylim[0]
    ax.text('1995', ypos, 'Training')
    ax.text('2002-3',ypos, 'Validation')

# %% [markdown]
# # 17.1

# %%
sept11 = pd.read_csv("Sept11Travel.csv")
sept11
# Out:
#     Month-Year    AirRPM     RailPM  VMT_billions
# 0       Jan-90  35153577  454115779        163.28
# 1       Feb-90  32965187  435086002        153.25
# 2       Mar-90  39993913  568289732        178.42
# 3       Apr-90  37981886  568101697        178.68
# 4       May-90  38419672  539628385        188.88
# ..         ...       ...        ...           ...
# 167      3-Dec  57795908  489403554        237.60
# 168      4-Jan  53447972  410338691        217.30
# 169      4-Feb  52608801  389778365        210.40
# 170      4-Mar  63600019  453014590        247.50
# 171      4-Apr  61887720  471116666        245.40
#
# [172 rows x 4 columns]

# %%
form19 = "%b-%y"
form20 = "%y-%b"
sept11['Date'] = pd.to_datetime(sept11['Month-Year'].iloc[0:132], format = form19)
sept11['Month-Year'].iloc[132:172] = '0' + sept11['Month-Year'].iloc[132:172]
sept11['Date'].iloc[132:172] = pd.to_datetime(sept11['Month-Year'].iloc[132:172], format = form20)
sept11
# Out:
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#     Month-Year    AirRPM     RailPM  VMT_billions       Date
# 0       Jan-90  35153577  454115779        163.28 1990-01-01
# 1       Feb-90  32965187  435086002        153.25 1990-02-01
# 2       Mar-90  39993913  568289732        178.42 1990-03-01
# 3       Apr-90  37981886  568101697        178.68 1990-04-01
# 4       May-90  38419672  539628385        188.88 1990-05-01
# ..         ...       ...        ...           ...        ...
# 167     03-Dec  57795908  489403554        237.60 2003-12-01
# 168     04-Jan  53447972  410338691        217.30 2004-01-01
# ...

# %%
sept11.iloc[140]
# Out:
# Month-Year                   01-Sep
# AirRPM                     39106905
# RailPM                    446266947
# VMT_billions                 224.57
# Date            2001-09-01 00:00:00
# Name: 140, dtype: object

# %%
before = sept11.iloc[0:140]
after = sept11.iloc[140:172]

# %% [markdown]
# ## a

# %%
air = pd.Series(before.AirRPM.values, index=before.Date, name = 'Air')
rail = pd.Series(before.RailPM.values, index=before.Date, name = 'Rail')
car = pd.Series(before.VMT_billions.values, index=before.Date, name = 'Car')

air.index = pd.DatetimeIndex(air.index, freq = air.index.inferred_freq)
rail.index = pd.DatetimeIndex(rail.index, freq = rail.index.inferred_freq)
car.index = pd.DatetimeIndex(car.index, freq = car.index.inferred_freq)

plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
ax = air.plot(color='red')
ax.set_xlabel('Air')
plt.subplot(3,1,2)
ax = rail.plot(color='blue')
ax.set_xlabel('Rail')
plt.subplot(3,1,3)
ax = car.plot(color='green')
ax.set_xlabel('Car')
# Out:
# Text(0.5, 0, 'Car')

# %% [markdown]
# ### i
# air - 점점 늘어나는 추세, 1년단위로 동일한 계절변동
# rail - 약간 줄어드는 추세, 이 또한 1년 단위로 동일한 계절변동
# car - 점점 늘어나는 추세, 1년단위로 동일한 계절변동

# %% [markdown]
# ## b

# %% [markdown]
# 추세를 이용한 선형회귀모형

# %% [markdown]
# ## c (⭐️)
# 예측변수 : 계절을 표현할 수 있는 새로운 범주형 변수의 가변수들
# 반응변수 : log(Y)를 사용하지 않은 그냥 Y

# %% [markdown]
# ## d(⭐️⭐️⭐️⭐️⭐️) 모델을 어떻게 만들어야 하는?
# https://sigmundojr.medium.com/seasonality-in-python-additive-or-multiplicative-model-d4b9cf1f48a7

# %%
air_df = tsatools.add_trend(air, trend='c') # 추세 x. 그냥 상수 (const) 변수 추가
air_df['Month'] = air_df.index.month # 계절을 나타내는 (월별) 변수 새로 생성
air_df
# Out:
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                  Air  const  Month
# Date
# 1990-01-01  35153577    1.0    1.0
# 1990-02-01  32965187    1.0    2.0
# 1990-03-01  39993913    1.0    3.0
# 1990-04-01  37981886    1.0    4.0
# 1990-05-01  38419672    1.0    5.0
# ...              ...    ...    ...
# NaT         59801562    1.0    NaN
# NaT         60246477    1.0    NaN
# NaT         64987625    1.0    NaN
# NaT         68573410    1.0    NaN
# NaT         69003617    1.0    NaN
#
# [140 rows x 3 columns]

# %%
ridership_lm_season = sm.ols(formula='np.sqaure(Air) ~ C(Month)', data = air_df).fit()

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(9, 7.5))

ridership_lm_season.predict(before_df).plot(ax=axes[0], color='C1')

residual = train_df.Ridership - ridership_lm_season.predict(air_df)
residual.plot(ax=axes[1],color="C1")

SinglegraphLayout(axes, before_df)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/__init__.py in __getattr__(attr)
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#
# ...

# %% [markdown]
# # 17.2

# %%
work = pd.read_csv("CanadianWorkHours.csv")
work
# Out:
#     Year  Hours
# 0   1966   37.2
# 1   1967   37.0
# 2   1968   37.4
# 3   1969   37.5
# 4   1970   37.7
# 5   1971   37.7
# 6   1972   37.4
# 7   1973   37.2
# 8   1974   37.3
# 9   1975   37.2
# 10  1976   36.9
# 11  1977   36.7
# 12  1978   36.7
# 13  1979   36.5
# 14  1980   36.3
# 15  1981   35.9
# 16  1982   35.8
# 17  1983   35.9
# 18  1984   36.0
# 19  1985   35.7
# 20  1986   35.6
# 21  1987   35.2
# 22  1988   34.8
# 23  1989   35.3
# 24  1990   35.6
# 25  1991   35.6
# 26  1992   35.6
# 27  1993   35.9
# 28  1994   36.0
# 29  1995   35.7
# 30  1996   35.7
# 31  1997   35.5
# 32  1998   35.6
# 33  1999   36.3
# 34  2000   36.5

# %%
work_sr = work

# %%
df = pd.Series(work.Hours.values, index=work.Year, name = 'df')
ax = df.plot()

# %% [markdown]
# ## a
# 이차 추세 모델

# %% [markdown]
# ## b
# 양의 상관관계를 띤다. 전반적으로 같은 방향성을 갖고 있으므로

# %% [markdown]
# ## c

# %%
tsaplots.plot_acf(work.Hours) # tsaplots.plot_acf() : ㅈㅏ기상관함수 plotting
plt.show()
print(stattools.acf(work.Hours))
# Out:
# [ 1.          0.92827786  0.83907157  0.75243724  0.66489363  0.5711929
#   0.47340041  0.36878832  0.26492963  0.16369487  0.04740503 -0.08222525
#  -0.18483692 -0.26088464 -0.31045932 -0.34629088 -0.3809144  -0.4222536
#  -0.43949689 -0.43855458 -0.41680275 -0.38853008 -0.35354174 -0.29956243
#  -0.25714397 -0.22719563 -0.2070935  -0.17875588 -0.14213083 -0.11126022
#  -0.07402466 -0.04542725 -0.01976552  0.00544158  0.00761791]
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
# ...

# %% [markdown]
# 10-지연일때부터 음의 상관관계를 띤다.
# 계속 하강하다가 1988년을 기점으로 그래프가 꺾여서 이런 ACF가 나타나는 것 같다.

# %% [markdown]
# # 17.3

# %%
df = pd.read_csv("ToysRUsRevenues.csv")
df
# Out:
#     Index QuarterYear  Revenue(in million $) Quarter
# 0       1       Q1-92                   1026      Q1
# 1       2       Q2-92                   1056      Q2
# 2       3       Q3-92                   1182      Q3
# 3       4       Q4-92                   2861      Q4
# 4       5       Q1-93                   1172      Q1
# 5       6       Q2-93                   1249      Q2
# 6       7       Q3-93                   1346      Q3
# 7       8       Q4-93                   3402      Q4
# 8       9       Q1-94                   1286      Q1
# 9      10       Q2-94                   1317      Q2
# 10     11       Q3-94                   1449      Q3
# 11     12       Q4-94                   3893      Q4
# 12     13       Q1-95                   1462      Q1
# 13     14       Q2-95                   1452      Q2
# 14     15       Q3-95                   1631      Q3
# 15     16       Q4-95                   4200      Q4

# %%
for j in range(0,16,4):
    df.QuarterYear[j] =  df.QuarterYear[j].replace('Q1','03')
    df.QuarterYear[j+1] = df.QuarterYear[j+1].replace('Q2','06')
    df.QuarterYear[j+2] = df.QuarterYear[j+2].replace('Q3','09')
    df.QuarterYear[j+3] = df.QuarterYear[j+3].replace('Q4','12')
# Out:
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/1079072802.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.QuarterYear[j] =  df.QuarterYear[j].replace('Q1','03')
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/1079072802.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.QuarterYear[j+1] = df.QuarterYear[j+1].replace('Q2','06')
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/1079072802.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df = df.rename(columns={'Revenue(in million $)':'Revenue'})
df = df.drop(columns=['Index'])

# %%
df = df.set_index('Date')
df
# Out:
#            QuarterYear  Revenue Quarter
# Date
# 1992-03-01       03-92     1026      Q1
# 1992-06-01       06-92     1056      Q2
# 1992-09-01       09-92     1182      Q3
# 1992-12-01       12-92     2861      Q4
# 1993-03-01       03-93     1172      Q1
# 1993-06-01       06-93     1249      Q2
# 1993-09-01       09-93     1346      Q3
# 1993-12-01       12-93     3402      Q4
# 1994-03-01       03-94     1286      Q1
# 1994-06-01       06-94     1317      Q2
# 1994-09-01       09-94     1449      Q3
# 1994-12-01       12-94     3893      Q4
# 1995-03-01       03-95     1462      Q1
# 1995-06-01       06-95     1452      Q2
# 1995-09-01       09-95     1631      Q3
# 1995-12-01       12-95     4200      Q4

# %%
df['Date'] = pd.to_datetime(df.QuarterYear, format='%m-%y')
df_ts = pd.Series(df.Revenue.values, index = df.Date, name='revenue')
df_ts.index = pd.DatetimeIndex(df_ts.index, freq=df_ts.index.inferred_freq)

# %%
df_ = tsatools.add_trend(df_ts, trend='ct') # 추세 x. 그냥 상수 (const) 변수 추가
df_['Quarter'] = df['Quarter']
# Out:
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df_
# Out:
#             revenue  const  trend Quarter
# Date
# 1992-03-01     1026    1.0    1.0      Q1
# 1992-06-01     1056    1.0    2.0      Q2
# 1992-09-01     1182    1.0    3.0      Q3
# 1992-12-01     2861    1.0    4.0      Q4
# 1993-03-01     1172    1.0    5.0      Q1
# 1993-06-01     1249    1.0    6.0      Q2
# 1993-09-01     1346    1.0    7.0      Q3
# 1993-12-01     3402    1.0    8.0      Q4
# 1994-03-01     1286    1.0    9.0      Q1
# 1994-06-01     1317    1.0   10.0      Q2
# 1994-09-01     1449    1.0   11.0      Q3
# 1994-12-01     3893    1.0   12.0      Q4
# 1995-03-01     1462    1.0   13.0      Q1
# 1995-06-01     1452    1.0   14.0      Q2
# 1995-09-01     1631    1.0   15.0      Q3
# 1995-12-01     4200    1.0   16.0      Q4

# %%
for j in range(0,16,4):
    df_.Quarter[j] =  df_.Quarter[j].replace('Q1','03')
    df_.Quarter[j+1] = df_.Quarter[j+1].replace('Q2','06')
    df_.Quarter[j+2] = df_.Quarter[j+2].replace('Q3','09')
    df_.Quarter[j+3] = df_.Quarter[j+3].replace('Q4','12')
# Out:
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/2392863759.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_.Quarter[j] =  df_.Quarter[j].replace('Q1','03')
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/2392863759.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_.Quarter[j+1] = df_.Quarter[j+1].replace('Q2','06')
# /var/folders/z6/j3q11gsn0ls8wtjzqj36nssm0000gp/T/ipykernel_2347/2392863759.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_
# Out:
#             revenue  const  trend Quarter
# Date
# 1992-03-01     1026    1.0    1.0      03
# 1992-06-01     1056    1.0    2.0      06
# 1992-09-01     1182    1.0    3.0      09
# 1992-12-01     2861    1.0    4.0      12
# 1993-03-01     1172    1.0    5.0      03
# 1993-06-01     1249    1.0    6.0      06
# 1993-09-01     1346    1.0    7.0      09
# 1993-12-01     3402    1.0    8.0      12
# 1994-03-01     1286    1.0    9.0      03
# 1994-06-01     1317    1.0   10.0      06
# 1994-09-01     1449    1.0   11.0      09
# 1994-12-01     3893    1.0   12.0      12
# 1995-03-01     1462    1.0   13.0      03
# 1995-06-01     1452    1.0   14.0      06
# 1995-09-01     1631    1.0   15.0      09
# 1995-12-01     4200    1.0   16.0      12

# %%
revenue_lm_trendseason = sm.ols(formula='revenue ~ trend + np.square(trend) + C(Quarter)', data = df_).fit()

# %% [markdown]
# ## b

# %% [markdown]
# ### i, ii
# 음 잘 모르겟..

# %% [markdown]
# 조정을 어떻게 하는건데....

# %% [markdown]
# # 17.4

# %%
df = pd.read_csv("WalMartStock.csv")
df.head()
# Out:
#        Date  Close
# 0  5-Feb-01  53.84
# 1  6-Feb-01  53.20
# 2  7-Feb-01  54.66
# 3  8-Feb-01  52.30
# 4  9-Feb-01  50.40

# %%
df['Date'] = pd.to_datetime(df.Date, format='%d-%b-%y')
df_ts = pd.Series(df.Close.values, index = df.Date, name='close')
df_ts.index = pd.DatetimeIndex(df_ts.index, freq=df_ts.index.inferred_freq)

# %%
df_ = tsatools.add_trend(df_ts, trend='t') 
df_['Month'] = df_.index.month
# Out:
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df_
# Out:
#             close  trend  Month
# Date
# 2001-02-05  53.84    1.0      2
# 2001-02-06  53.20    2.0      2
# 2001-02-07  54.66    3.0      2
# 2001-02-08  52.30    4.0      2
# 2001-02-09  50.40    5.0      2
# ...           ...    ...    ...
# 2002-01-29  57.91  244.0      1
# 2002-01-30  59.75  245.0      1
# 2002-01-31  59.98  246.0      1
# 2002-02-01  59.26  247.0      2
# 2002-02-04  58.90  248.0      2
#
# [248 rows x 3 columns]

# %%
formula = 'close ~ trend + np.square(trend) + C(Month)'
df_lm_trendseason = sm.ols(formula = formula, data=df_).fit()
df_res_arima = ARIMA(df_lm_trendseason.resid, order = (1,0,0), freq='MS').fit()
# ARIMA 코드 ??? 
# train_lm_trendseason.resid : 잔차 
# fit() - trend='nc' : 상수를 포함하지 않음. trend='c' : 상수를 포함함
# fit() - disp : True이면 수렴 정보를 출력 / 0이면 출력 안 함


print('Forecast {0:.3f} [{1[0][0]:.3f}, {1[0][1]:.3f}]'.format(forecast, conf_int))
# Out:
# /Users/JAE111/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ## b
# AR(1)모델의 기울기의 계수

# %% [markdown]
# # 17.5

# %%
df = pd.read_csv("DepartmentStoreSales.csv")
df
# Out:
#     Quarter   Sales
# 0         1   50147
# 1         2   49325
# 2         3   57048
# 3         4   76781
# 4         5   48617
# 5         6   50898
# 6         7   58517
# 7         8   77691
# 8         9   50862
# 9        10   53028
# 10       11   58849
# 11       12   79660
# 12       13   51640
# 13       14   54119
# 14       15   65681
# 15       16   85175
# 16       17   56405
# 17       18   60031
# 18       19   71486
# 19       20   92183
# 20       21   60800
# 21       22   64900
# 22       23   76997
# 23       24  103337

# %% [markdown]
# ## a

# %% [markdown]
# 매출에 로그를 취한다.

# %% [markdown]
# ## b

# %%
df['Date'] = pd.to_datetime(df.Quarter, format='%d')
df_ts = pd.Series(df.Sales.values, index = df.Date, name='Sales')
df_ts.index = pd.DatetimeIndex(df_ts.index, freq=df_ts.index.inferred_freq)

# %%
df_ = tsatools.add_trend(df_ts, trend='t') 
df_['day'] = df_.index.day

# %%
train_df = df_[:20]
valid_df = df_[20:]

# %%
valid_df
# Out:
#              Sales  trend  day
# Date
# 1900-01-21   60800   21.0   21
# 1900-01-22   64900   22.0   22
# 1900-01-23   76997   23.0   23
# 1900-01-24  103337   24.0   24

# %%
ridership_lm_trendseason = sm.ols(formula='np.log(Sales) ~ trend + C(day)', data = train_df).fit()

# %% [markdown]
# ## c
# 높다.

# %%
ridership_lm_trendseason.predict(valid_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/patsy/categorical.py in categorical_to_int(data, levels, NA_action, origin)
#     345             try:
# --> 346                 out[i] = level_to_int[value]
#     347             except KeyError:
#
# KeyError: 21
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1076             try:
# -> 1077                 exog = dmatrix(design_info, exog, return_type="dataframe")
#    1078             except Exception as exc:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py in dmatrix(formula_like, data, eval_env, NA_action, return_type)
# ...

# %%
train_df
# Out:
#             Sales  trend  day
# Date
# 1900-01-01  50147    1.0    1
# 1900-01-02  49325    2.0    2
# 1900-01-03  57048    3.0    3
# 1900-01-04  76781    4.0    4
# 1900-01-05  48617    5.0    5
# 1900-01-06  50898    6.0    6
# 1900-01-07  58517    7.0    7
# 1900-01-08  77691    8.0    8
# 1900-01-09  50862    9.0    9
# 1900-01-10  53028   10.0   10
# 1900-01-11  58849   11.0   11
# 1900-01-12  79660   12.0   12
# 1900-01-13  51640   13.0   13
# 1900-01-14  54119   14.0   14
# 1900-01-15  65681   15.0   15
# 1900-01-16  85175   16.0   16
# 1900-01-17  56405   17.0   17
# 1900-01-18  60031   18.0   18
# 1900-01-19  71486   19.0   19
# 1900-01-20  92183   20.0   20

# %%
valid_df
# Out:
#              Sales  trend  day
# Date
# 1900-01-21   60800   21.0   21
# 1900-01-22   64900   22.0   22
# 1900-01-23   76997   23.0   23
# 1900-01-24  103337   24.0   24

# %% [markdown]
# ## f
# 계절변동은 잘 반영되지 않는다.

# %% [markdown]
# ## g
# 잔차를 AR모델에 적용
